# %%
# 시청 기록 파일 가져오기
import pandas as pd
import json

df=pd.read_json("시청 기록.json")

# %%
# 데이터 수정 => 최적화.
df.drop(columns= ["header","titleUrl","products","activityControls"], inplace = True)
# Out:
#                                                    title  \
# 0      [𝙋𝙡𝙖𝙮𝙡𝙞𝙨𝙩] 상실의 시대…내가 사랑한 나의 미도리 | 감성 피아노 을(를) ...
# 1      과거에는 컴퓨터를 쓰기 위해 복잡한 코딩을 배워야 했지만, 이제는 컴퓨터랑 대화만 ...
# 2      요즘 생각 : 너무 빠르고 무섭고 걱정도되고 슬프기도 하고 할수있는 것은 없고 그렇...
# 3      Blue Bird (2022 ver.) - Naruto Shippuuden OP3 ...
# 4                                 TWO-lives 을(를) 시청했습니다.
# ...                                                  ...
# 13043                            승준이 우유 대소동 을(를) 시청했습니다.
# 13044                      레전드 사건 발생 ㅋㅋㅋㅋㅋㅋ 을(를) 시청했습니다.
# 13045                            의문의 중고차 딜러 을(를) 시청했습니다.
# 13046                               첫 번째 레슨 을(를) 시청했습니다.
# 13047                              저미니스트의 삶 을(를) 시청했습니다.
#
#                                                subtitles  \
# 0      [{'name': '노르웨이 숲 Norwegian Wood', 'url': 'htt...
# 1      [{'name': 'BZCF | 비즈까페', 'url': 'https://www.y...
# 2      [{'name': 'BZCF | 비즈까페', 'url': 'https://www.y...
# ...

# %%
df
# Out:
#                                                    title  \
# 0      [𝙋𝙡𝙖𝙮𝙡𝙞𝙨𝙩] 상실의 시대…내가 사랑한 나의 미도리 | 감성 피아노 을(를) ...
# 1      과거에는 컴퓨터를 쓰기 위해 복잡한 코딩을 배워야 했지만, 이제는 컴퓨터랑 대화만 ...
# 2      요즘 생각 : 너무 빠르고 무섭고 걱정도되고 슬프기도 하고 할수있는 것은 없고 그렇...
# 3      Blue Bird (2022 ver.) - Naruto Shippuuden OP3 ...
# 4                                 TWO-lives 을(를) 시청했습니다.
# ...                                                  ...
# 13043                            승준이 우유 대소동 을(를) 시청했습니다.
# 13044                      레전드 사건 발생 ㅋㅋㅋㅋㅋㅋ 을(를) 시청했습니다.
# 13045                            의문의 중고차 딜러 을(를) 시청했습니다.
# 13046                               첫 번째 레슨 을(를) 시청했습니다.
# 13047                              저미니스트의 삶 을(를) 시청했습니다.
#
#                                                subtitles  \
# 0      [{'name': '노르웨이 숲 Norwegian Wood', 'url': 'htt...
# 1      [{'name': 'BZCF | 비즈까페', 'url': 'https://www.y...
# 2      [{'name': 'BZCF | 비즈까페', 'url': 'https://www.y...
# ...
