# %%
# 시청 기록 파일 가져오기
import pandas as pd
import json

df=pd.read_json("시청 기록.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 5
#       2 import pandas as pd
#       3 import json
# ----> 5 df=pd.read_json("시청 기록.json")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
#     800     date_unit=date_unit,
#     801     encoding=encoding,
#     802     lines=lines,
#     803     chunksize=chunksize,
#     804     compression=compression,
#     805     nrows=nrows,
#     806     storage_options=storage_options,
#     807     encoding_errors=encoding_errors,
#     808     dtype_backend=dtype_backend,
#     809     engine=engine,
#     810 )
#     812 if chunksize:
#     813     return json_reader
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:904, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902     self.data = filepath_or_buffer
#     903 elif self.engine == "ujson":
# --> 904     data = self._get_data_from_filepath(filepath_or_buffer)
#     905     self.data = self._preprocess_data(data)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:960, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     952     filepath_or_buffer = self.handles.handle
#     953 elif (
#     954     isinstance(filepath_or_buffer, str)
#     955     and filepath_or_buffer.lower().endswith(
#    (...)    958     and not file_exists(filepath_or_buffer)
#     959 ):
# --> 960     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961 else:
#     962     warnings.warn(
#     963         "Passing literal json to 'read_json' is deprecated and "
#     964         "will be removed in a future version. To read from a "
#    (...)    967         stacklevel=find_stack_level(),
#     968     )
#
# FileNotFoundError: File 시청 기록.json does not exist

# %%
# 데이터 수정 => 최적화.
df.drop(columns= ["header","titleUrl","products","activityControls"], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # 데이터 수정 => 최적화.
# ----> 2 df.drop(columns= ["header","titleUrl","products","activityControls"], inplace = True)
#
# NameError: name 'df' is not defined

# %%
# column 내 필요 없는 문자 대
df["title"]=df["title"].str.replace("을(를) 시청했습니다.","")
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # column 내 필요 없는 문자 대
# ----> 2 df["title"]=df["title"].str.replace("을(를) 시청했습니다.","")
#       3 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# isinstance(sub_list,list) => sub_list라는 변수에 들어온 녀석이 리스트[] 자료형인지 확인한다.
# isinstance(확인하고자 하는 데이터 값, 확인하고자 하는 데이터 타입) => True or False
# len(sub_list) > 0 => 아예 없는 경우 방지(안전장치)
#
# sub_list[0] 리스트의 1번째 칸에 있는 딕셔너리{} 선택
# get('name') => name이라는 key에 연결된 값(채널명)을 가져온다.

# %%
# 채널 이름 추출
def extract_channel(sub_list):
    if isinstance(sub_list, list) and len(sub_list)>0:
        return sub_list[0].get("name")
    return "Unknown"

df["channel"] = df["subtitles"].apply(extract_channel)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       4         return sub_list[0].get("name")
#       5     return "Unknown"
# ----> 7 df["channel"] = df["subtitles"].apply(extract_channel)
#       8 df
#
# NameError: name 'df' is not defined

# %%
# 기존 데이터 삭제
df.drop(columns=["subtitles"], inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # 기존 데이터 삭제
# ----> 2 df.drop(columns=["subtitles"], inplace = True)
#       3 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# to_datetime => 문자열이었던 시간을 datetime 자료형으로 전환한다. 만약 시간 형식이 제각각이라면
# format = 'mixed' / utc값으로 시작한다 확정짓고
#
# 한국시간을 위해. dt.tz_convert("Asia/Seoul")로 변경  만약 다른 나라 Asia/Tokyo

# %%
#문자열을 날짜/시간 각체로 변환(UTC 기능)
df['time']=pd.to_datetime(df['time'], format ='mixed', utc =True)

df['time_kst']=df['time'].dt.tz_convert("Asia/Seoul")

#년,월, 일, 시, 요일 따로 추출
df['year']= df['time_kst'].dt.year
df['month']=df['time_kst'].dt.month
df['day'] = df['time_kst'].dt.day
df['hour'] = df['time_kst'].dt.hour
df['weekday']=df['time_kst'].dt.day_name()

print(df['day'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 #문자열을 날짜/시간 각체로 변환(UTC 기능)
# ----> 2 df['time']=pd.to_datetime(df['time'], format ='mixed', utc =True)
#       4 df['time_kst']=df['time'].dt.tz_convert("Asia/Seoul")
#       6 #년,월, 일, 시, 요일 따로 추출
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rcParams["font.family"]="Malgun Gothic"
matplotlib.rcParams["axes.unicode_minus"] =False

# %%
labels_weekday=["월","화","수","목","금","토","일"]
plt.bar(labels_weekday,df["weekday"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 labels_weekday=["월","화","수","목","금","토","일"]
# ----> 2 plt.bar(labels_weekday,df["weekday"])
#
# NameError: name 'df' is not defined

# %%
# 매주 평균 시청횟수를 알고 싶다
